# %%
import numpy as np 
import pandas as pd

# %%
covidPath = "C:/Users/camil/OneDrive/Bureau/COVID19_03242020_ByCounty.xlsx"
covid = pd.read_excel(covidPath)

# %%
covid.head()
# Out:
#    OBJECTID_12_13  OBJECTID  DEPCODE  COUNTY COUNTYNAME  \
# 0               1         1       21      41  GILCHRIST
# 1               2         2       54     107     PUTNAM
# 2               3         3       62     123     TAYLOR
# 3               4         4       46      91   OKALOOSA
# 4               5         5        7      13    CALHOUN
#
#                   DATESTAMP    ShapeSTAre    ShapeSTLen  OBJECTID_1  \
# 0  2000-05-16T00:00:00.000Z  9.908353e+09  4.873000e+05          21
# 1  2000-05-16T00:00:00.000Z  2.305869e+10  7.629677e+05          54
# 2  2000-05-16T00:00:00.000Z  2.891747e+10  8.772527e+05          62
# 3  2000-05-16T00:00:00.000Z  2.562159e+10  1.087058e+06          46
# 4  2000-05-16T00:00:00.000Z  1.604809e+10  6.313440e+05           7
#
#     County_1  ... T_negative  T_pending  T_positive  FLandNonFLDeaths  \
# 0  Gilchrist  ...          7          0           0                 0
# 1     Putnam  ...         81         28           2                 0
# ...

# %%
covid.describe()
# Out:
#        OBJECTID_12_13    OBJECTID     DEPCODE      COUNTY    ShapeSTAre  \
# count        68.00000   68.000000   68.000000   68.000000  6.700000e+01
# mean         34.50000   48.191176   48.191176   80.705882  2.342932e+10
# std          19.77372  118.610646  118.610646  119.456613  1.149607e+10
# min           1.00000    1.000000    1.000000    1.000000  6.963394e+09
# 25%          17.75000   17.750000   17.750000   34.500000  1.620782e+10
# 50%          34.50000   34.500000   34.500000   68.000000  1.964766e+10
# 75%          51.25000   51.250000   51.250000  101.500000  2.820891e+10
# max          68.00000  999.000000  999.000000  999.000000  6.149159e+10
#
#          ShapeSTLen  OBJECTID_1  OBJECTID_12   DEPCODE_1     COUNTYN  ...  \
# count  6.700000e+01    68.00000     68.00000   68.000000   68.000000  ...
# mean   1.048655e+06    34.50000     34.50000   48.191176   80.705882  ...
# std    5.982756e+05    19.77372     19.77372  118.610646  119.456613  ...
# ...
